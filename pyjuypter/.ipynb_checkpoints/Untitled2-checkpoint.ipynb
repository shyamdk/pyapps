# %%
import pandas
df1 = pandas.read_json("http://pythonhow.com/supermarkets.json")
df1
df1 = df1.set_index("Employees")
df1
df1.loc[8:25,"Country": "Name"]
df1.loc[:,"Country": "Name"]
df1
# Out:
#            ID          Address           City             State Country  \
# Employees
# 8           1     3666 21st St  San Francisco          CA 94114     USA
# 15          2   735 Dolores St  San Francisco          CA 94119     USA
# 25          3      332 Hill St  San Francisco  California 94114     USA
# 10          4     3995 23rd St  San Francisco          CA 94114     USA
# 12          5  1056 Sanchez St  San Francisco        California     USA
# 20          6  551 Alvarado St  San Francisco          CA 94114     USA
#
#                   Name
# Employees
# 8              Madeira
# 15         Bready Shop
# 25         Super River
# 10          Ben's Shop
# 12             Sanchez
# 20          Richvalley

# %%
df1.iloc[1:3,1:3]
# Out:
#                   Address           City
# Employees
# 15         735 Dolores St  San Francisco
# 25            332 Hill St  San Francisco

# %%
df1.drop("Address", 1) #1 stand for column
# Out:
#            ID           City             State Country         Name
# Employees
# 8           1  San Francisco          CA 94114     USA      Madeira
# 15          2  San Francisco          CA 94119     USA  Bready Shop
# 25          3  San Francisco  California 94114     USA  Super River
# 10          4  San Francisco          CA 94114     USA   Ben's Shop
# 12          5  San Francisco        California     USA      Sanchez
# 20          6  San Francisco          CA 94114     USA   Richvalley

# %%
df1.drop(8, 0) #1 stand for row
# Out:
#            ID          Address           City             State Country  \
# Employees
# 15          2   735 Dolores St  San Francisco          CA 94119     USA
# 25          3      332 Hill St  San Francisco  California 94114     USA
# 10          4     3995 23rd St  San Francisco          CA 94114     USA
# 12          5  1056 Sanchez St  San Francisco        California     USA
# 20          6  551 Alvarado St  San Francisco          CA 94114     USA
#
#                   Name
# Employees
# 15         Bready Shop
# 25         Super River
# 10          Ben's Shop
# 12             Sanchez
# 20          Richvalley

# %%
df1.drop(df1.index[0:3],0)
# Out:
#            ID          Address           City       State Country        Name
# Employees
# 10          4     3995 23rd St  San Francisco    CA 94114     USA  Ben's Shop
# 12          5  1056 Sanchez St  San Francisco  California     USA     Sanchez
# 20          6  551 Alvarado St  San Francisco    CA 94114     USA  Richvalley

# %%
df1
df1["Continent"] = df1.shape[0]*["North America"]
df1
# Out:
#            ID          Address           City             State Country  \
# Employees
# 8           1     3666 21st St  San Francisco          CA 94114     USA
# 15          2   735 Dolores St  San Francisco          CA 94119     USA
# 25          3      332 Hill St  San Francisco  California 94114     USA
# 10          4     3995 23rd St  San Francisco          CA 94114     USA
# 12          5  1056 Sanchez St  San Francisco        California     USA
# 20          6  551 Alvarado St  San Francisco          CA 94114     USA
#
#                   Name      Continent
# Employees
# 8              Madeira  North America
# 15         Bready Shop  North America
# 25         Super River  North America
# 10          Ben's Shop  North America
# 12             Sanchez  North America
# 20          Richvalley  North America

# %%
df1["Continent"] = df1[Country]]+"'"+ "North America"
df1
# Out:
#   File "<ipython-input-36-09a2338f8aa3>", line 1
#     df1["Continent"] = df1[Country]]+"'"+ "North America"
#                                    ^
# SyntaxError: unmatched ']'

# %%
df1["Continent"] = df1[Country]+ "," + "North America"
df1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-6b5927f7185e> in <module>
# ----> 1 df1["Continent"] = df1[Country]+"'"+ "North America"
#       2 df1
#
# NameError: name 'Country' is not defined
